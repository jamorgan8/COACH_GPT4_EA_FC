# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
from datetime import date
from datetime import datetime
import unidecode
import re

# %matplotlib inline

# %%
all_players = pd.read_csv('../ChatGPT/gpt_food.csv')
players_stats = pd.read_csv('../ChatGPT/player_stats.csv')
current_squad = pd.read_csv('../ChatGPT/current_squad.csv')

# %%
all_players.head(2)
# Out:
#    Unnamed: 0  player_id  fifa_version  short_name             long_name  \
# 0           0     231747            24   k. mbappe  Kylian Mbappé Lottin
# 1           1     239085            24  e. haaland  Erling Braut Haaland
#
#   player_positions  overall  potential    value_eur  wage_eur  ...   ldm  \
# 0           ST, LW       91         94  181500000.0  230000.0  ...  63+3
# 1               ST       91         94  185000000.0  340000.0  ...  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# 0  63+3  63+3  68+3  63+3  54+3  54+3  54+3  63+3  18+3
# 1  63+3  63+3  62+3  60+3  62+3  62+3  62+3  60+3  19+3
#
# [2 rows x 100 columns]

# %%
players_stats.head(2)
# Out:
#    Unnamed: 0  rank      player_name  nationality  team position  \
# 0           0     1    Kylian Mbappe          NaN   NaN       ST
# 1           1     2  Alexia Putellas          NaN   NaN       CM
#
#    overall_rating  pace  shooting  passing  dribbling  defense  physical
# 0              91    97        90       80         92       36        78
# 1              91    82        90       91         92       72        78

# %%
current_squad.head(2)
# Out:
#    short_name
# 0  a. kandlec
# 1  j. roberts

# %%
players_stats['player_name'] = players_stats['player_name'].str.lower()
players_stats = players_stats.drop(columns = ['Unnamed: 0'])

players_stats[['first_name', 'last_name']] = players_stats['player_name'].str.split(' ', 1, expand = True)
players_stats
# Out:
#         rank      player_name  nationality  team position  overall_rating  \
# 0          1    kylian mbappe          NaN   NaN       ST              91
# 1          2  alexia putellas          NaN   NaN       CM              91
# 2          3   erling haaland          NaN   NaN       ST              91
# 3          4  kevin de bruyne          NaN   NaN       CM              91
# 4          5   aitana bonmati          NaN   NaN       CM              90
# ...      ...              ...          ...   ...      ...             ...
# 17321  17318    deven sawhney          NaN   NaN       LB              47
# 17322  17318      wang tengda          NaN   NaN       CM              47
# 17323  17318        wu yuhang          NaN   NaN      CDM              47
# 17324  17318        ye daoxin          NaN   NaN       CB              47
# 17325  17318          yin jie          NaN   NaN       CM              47
#
#        pace  shooting  passing  dribbling  defense  physical first_name  \
# 0        97        90       80         92       36        78     kylian
# 1        82        90       91         92       72        78     alexia
# 2        89        93       66         80       45        88     erling
# 3        72        88       94         87       65        78      kevin
# 4        81        84       83         91       75        73     aitana
# ...     ...       ...      ...        ...      ...       ...        ...
# 17321    62        26       34         42       43        57      deven
# 17322    61        37       45         48       43        47       wang
# 17323    56        34       43         45       43        51         wu
# 17324    58        28       33         39       49        48         ye
# 17325    57        37       46         46       38        57        yin
#
#        last_name
# 0         mbappe
# 1       putellas
# 2        haaland
# 3      de bruyne
# 4        bonmati
# ...          ...
# 17321    sawhney
# 17322     tengda
# 17323     yuhang
# 17324     daoxin
# 17325        jie
#
# [17326 rows x 14 columns]

# %%
current_squad[['first_name', 'last_name']] = current_squad['short_name'].str.split(' ', 1, expand = True)
current_squad
# Out:
#       short_name first_name  last_name
# 0     a. kandlec         a.    kandlec
# 1     j. roberts         j.    roberts
# 2    b. lefebvre         b.   lefebvre
# 3        d. lang         d.       lang
# 4      p. cooper         p.     cooper
# 5      c. santos         c.     santos
# 6     v. jonsson         v.    jonsson
# 7   s. contreras         s.  contreras
# 8      v. santos         v.     santos
# 9     l. nygaard         l.    nygaard
# 10      d. leroy         d.      leroy
# 11     g. santos         g.     santos
# 12      r. owusu         r.      owusu
# 13      m. smith         m.      smith
# 14    m. coleman         m.    coleman
# 15      g. busch         g.      busch
# 16      b. costa         b.      costa
# 17      j. jones         j.      jones
# 18    a. ibrahim         a.    ibrahim
# 19      m. jones         m.      jones
# 20  s. demetriou         s.  demetriou
# 21      d. thiam         d.      thiam
# 22    s. cameron         s.    cameron

# %%
current_squad_stats = current_squad.merge(players_stats, on = 'last_name', how = 'left')
current_squad_stats
# Out:
#      short_name first_name_x last_name     rank       player_name  \
# 0    a. kandlec           a.   kandlec      NaN               NaN
# 1    j. roberts           j.   roberts   1900.0    connor roberts
# 2    j. roberts           j.   roberts   4282.0   patrick roberts
# 3    j. roberts           j.   roberts   6934.0      marc roberts
# 4    j. roberts           j.   roberts   6934.0  rhiannon roberts
# ..          ...          ...       ...      ...               ...
# 193    d. thiam           d.     thiam  12084.0       demba thiam
# 194  s. cameron           s.   cameron   6934.0   tiffany cameron
# 195  s. cameron           s.   cameron  11071.0     lyall cameron
# 196  s. cameron           s.   cameron  13061.0      kyle cameron
# 197  s. cameron           s.   cameron  13830.0     innes cameron
#
#      nationality  team position  overall_rating  pace  shooting  passing  \
# 0            NaN   NaN      NaN             NaN   NaN       NaN      NaN
# 1            NaN   NaN       RB            75.0  78.0      61.0     71.0
# 2            NaN   NaN       RM            71.0  78.0      65.0     66.0
# 3            NaN   NaN       CB            68.0  44.0      24.0     42.0
# 4            NaN   NaN       CB            68.0  66.0      61.0     64.0
# ..           ...   ...      ...             ...   ...       ...      ...
# 193          NaN   NaN      RWB            63.0  72.0      25.0     48.0
# 194          NaN   NaN       ST            68.0  77.0      63.0     61.0
# 195          NaN   NaN      CAM            64.0  80.0      58.0     58.0
# 196          NaN   NaN       CB            62.0  55.0      34.0     46.0
# 197          NaN   NaN       ST            61.0  58.0      60.0     55.0
#
#      dribbling  defense  physical first_name_y
# 0          NaN      NaN       NaN          NaN
# 1         72.0     69.0      74.0       connor
# 2         77.0     28.0      40.0      patrick
# 3         43.0     67.0      77.0         marc
# 4         62.0     68.0      68.0     rhiannon
# ..         ...      ...       ...          ...
# 193       57.0     60.0      67.0        demba
# 194       71.0     67.0      65.0      tiffany
# 195       67.0     54.0      57.0        lyall
# 196       53.0     61.0      71.0         kyle
# 197       58.0     47.0      73.0        innes
#
# [198 rows x 16 columns]

# %%
current_squad_stats = pd.merge(current_squad, players_stats, on = 'last_name')
current_squad_stats = pd.merge(current_squad_stats, players_stats, on)
current_squad_stats
# Out:
#      short_name first_name_x last_name   rank       player_name  nationality  \
# 0    j. roberts           j.   roberts   1900    connor roberts          NaN
# 1    j. roberts           j.   roberts   4282   patrick roberts          NaN
# 2    j. roberts           j.   roberts   6934      marc roberts          NaN
# 3    j. roberts           j.   roberts   6934  rhiannon roberts          NaN
# 4    j. roberts           j.   roberts   6934     tyler roberts          NaN
# ..          ...          ...       ...    ...               ...          ...
# 189    d. thiam           d.     thiam  12084       demba thiam          NaN
# 190  s. cameron           s.   cameron   6934   tiffany cameron          NaN
# 191  s. cameron           s.   cameron  11071     lyall cameron          NaN
# 192  s. cameron           s.   cameron  13061      kyle cameron          NaN
# 193  s. cameron           s.   cameron  13830     innes cameron          NaN
#
#      team position  overall_rating  pace  shooting  passing  dribbling  \
# 0     NaN       RB              75    78        61       71         72
# 1     NaN       RM              71    78        65       66         77
# 2     NaN       CB              68    44        24       42         43
# 3     NaN       CB              68    66        61       64         62
# 4     NaN      CAM              68    72        65       63         72
# ..    ...      ...             ...   ...       ...      ...        ...
# 189   NaN      RWB              63    72        25       48         57
# 190   NaN       ST              68    77        63       61         71
# 191   NaN      CAM              64    80        58       58         67
# 192   NaN       CB              62    55        34       46         53
# 193   NaN       ST              61    58        60       55         58
#
#      defense  physical first_name_y
# 0         69        74       connor
# 1         28        40      patrick
# 2         67        77         marc
# 3         68        68     rhiannon
# 4         38        70        tyler
# ..       ...       ...          ...
# 189       60        67        demba
# 190       67        65      tiffany
# 191       54        57        lyall
# 192       61        71         kyle
# 193       47        73        innes
#
# [194 rows x 16 columns]
