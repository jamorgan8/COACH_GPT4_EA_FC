# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
from datetime import date
from datetime import datetime
import unidecode
import re

# %matplotlib inline

# %%
all_players = pd.read_csv('../DATA/gpt_food.csv')
players_stats = pd.read_csv('../DATA/player_stats.csv')

# %%
all_players.head(2)
# Out:
#    Unnamed: 0  player_id  fifa_version  short_name             long_name  \
# 0           0     231747            24   k. mbappe  Kylian Mbappé Lottin
# 1           1     239085            24  e. haaland  Erling Braut Haaland
#
#   player_positions  overall  potential    value_eur  wage_eur  ...   ldm  \
# 0           ST, LW       91         94  181500000.0  230000.0  ...  63+3
# 1               ST       91         94  185000000.0  340000.0  ...  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# 0  63+3  63+3  68+3  63+3  54+3  54+3  54+3  63+3  18+3
# 1  63+3  63+3  62+3  60+3  62+3  62+3  62+3  60+3  19+3
#
# [2 rows x 100 columns]

# %%
players_stats.head(2)
# Out:
#    Unnamed: 0      id            name  overall  pace  shooting  passing  \
# 0           0  231747   kylian mbappe       91    97        90       80
# 1           1  239085  erling haaland       91    89        93       66
#
#    dribbling  defense  physical
# 0         92       36        78
# 1         80       45        88

# %%
#normalize name
all_players['long_name'] = all_players['long_name'].str.lower()
all_players['long_name'] = all_players['long_name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
all_players.rename(columns = {'long_name':'name', 'player_id':'id'}, inplace = True)
all_players = all_players.drop(columns = ['Unnamed: 0'])
all_players.head()
# Out:
#        id  fifa_version    short_name                            name  \
# 0  231747            24     k. mbappe            kylian mbappe lottin
# 1  239085            24    e. haaland            erling braut haaland
# 2  192985            24  k. de bruyne                 kevin de bruyne
# 3  158023            24      l. messi  lionel andres messi cuccittini
# 4  165153            24    k. benzema                   karim benzema
#
#   player_positions  overall  potential    value_eur  wage_eur  age  ...   ldm  \
# 0           ST, LW       91         94  181500000.0  230000.0   24  ...  63+3
# 1               ST       91         94  185000000.0  340000.0   22  ...  63+3
# 2          CM, CAM       91         91  103000000.0  350000.0   32  ...  80+3
# 3          CF, CAM       90         90   41000000.0   23000.0   36  ...  63+3
# 4           CF, ST       90         90   51000000.0   95000.0   35  ...  64+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# ...

# %%
to_merge = all_players[['id', 'player_positions', 'club_position', 'value_eur', 'wage_eur', 'club_name', 'preferred_foot', 'player_tags', 'player_traits']]
to_merge
# Out:
#            id player_positions club_position    value_eur  wage_eur  \
# 0      231747           ST, LW            LW  181500000.0  230000.0
# 1      239085               ST            ST  185000000.0  340000.0
# 2      192985          CM, CAM           SUB  103000000.0  350000.0
# 3      158023          CF, CAM            RF   41000000.0   23000.0
# 4      165153           CF, ST            RS   51000000.0   95000.0
# ...       ...              ...           ...          ...       ...
# 18345  273759               CB           RES     100000.0     500.0
# 18346  269013               CB           SUB     100000.0    1000.0
# 18347  272748               ST           RES     100000.0    2000.0
# 18348  269534               CM           SUB      90000.0    1000.0
# 18349  269541              CDM           RES      70000.0    1000.0
#
#                  club_name preferred_foot  \
# 0      Paris Saint Germain          Right
# 1          Manchester City           Left
# ...

# %%
combined = pd.merge(players_stats, to_merge, on = 'id', how = 'left')
combined = combined.drop(columns = ['Unnamed: 0'])
combined
# Out:
#            id             name  overall  pace  shooting  passing  dribbling  \
# 0      231747    kylian mbappe       91    97        90       80         92
# 1      239085   erling haaland       91    89        93       66         80
# 2      192985  kevin de bruyne       91    72        88       94         87
# 3      158023     lionel messi       90    80        87       90         94
# 4      165153    karim benzema       90    79        88       83         87
# ...       ...              ...      ...   ...       ...      ...        ...
# 15840  266249   cvl remtluanga       47    62        41       46         48
# 15841  269541        wu yuhang       47    56        34       43         45
# 15842  269534          yin jie       47    57        37       46         46
# 15843  272761     lyu jiaqiang       47    56        26       28         33
# 15844  272748     mijit mewlan       47    68        46       38         46
#
# ...

# %%
squad_name = ['Plymouth Argyle']
current_squad = combined.loc[combined['club_name'].isin(squad_name)]
current_squad
# Out:
#            id                 name  overall  pace  shooting  passing  \
# 3304   240987       michael cooper       71    70        69       67
# 3499   243353           bali mumba       71    84        60       65
# 5000   228366  macaulay gillesphey       69    53        41       53
# 5317   252066            finn azaz       69    74        64       66
# 5444   222576          pleguezuelo       69    78        35       57
# 5458   237943            dan scarr       69    52        40       46
# 6293   192231          joe edwards       68    68        59       63
# 7893   226084          ryan hardie       66    86        64       48
# 7897   213665      jordan houghton       66    59        51       64
# 8085   253461          luke cundle       66    67        58       65
# 8424   251306         adam randell       66    76        62       65
# 8468   252796     morgan whittaker       66    74        65       58
# 8472   242423        callum wright       66    67        61       64
# ...

# %%
len(current_squad)
# Out:
# 27

# %%
current_squad.to_csv('../ChatGPT/test_squad.csv')
combined.to_csv('../ChatGPT/combined.csv')
