# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
from datetime import date
from datetime import datetime
import unidecode

# %matplotlib inline

# %%
all_players = pd.read_csv('../data/UP_male_players.csv')
all_players.head(2)
# Out:
# C:\Users\jamor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (98) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    player_id  fifa_version  short_name             long_name player_positions  \
# 0     231747            24   K. Mbappé  Kylian Mbappé Lottin           ST, LW
# 1     239085            24  E. Haaland  Erling Braut Haaland               ST
#
#    overall  potential    value_eur  wage_eur  age  ...   ldm   cdm   rdm  \
# 0       91         94  181500000.0  230000.0   24  ...  63+3  63+3  63+3
# 1       91         94  185000000.0  340000.0   22  ...  63+3  63+3  63+3
#
#     rwb    lb   lcb    cb   rcb    rb    gk
# 0  68+3  63+3  54+3  54+3  54+3  63+3  18+3
# 1  62+3  60+3  62+3  62+3  62+3  60+3  19+3
#
# [2 rows x 99 columns]

# %%
fc_24 = all_players[all_players['fifa_version'] == 24]
fc_24.head(2)
# Out:
#    player_id  fifa_version  short_name             long_name player_positions  \
# 0     231747            24   K. Mbappé  Kylian Mbappé Lottin           ST, LW
# 1     239085            24  E. Haaland  Erling Braut Haaland               ST
#
#    overall  potential    value_eur  wage_eur  age  ...   ldm   cdm   rdm  \
# 0       91         94  181500000.0  230000.0   24  ...  63+3  63+3  63+3
# 1       91         94  185000000.0  340000.0   22  ...  63+3  63+3  63+3
#
#     rwb    lb   lcb    cb   rcb    rb    gk
# 0  68+3  63+3  54+3  54+3  54+3  63+3  18+3
# 1  62+3  60+3  62+3  62+3  62+3  60+3  19+3
#
# [2 rows x 99 columns]

# %%
fc_24
# Out:
#        player_id  fifa_version     short_name                       long_name  \
# 0         231747            24      K. Mbappé            Kylian Mbappé Lottin
# 1         239085            24     E. Haaland            Erling Braut Haaland
# 2         192985            24   K. De Bruyne                 Kevin De Bruyne
# 3         158023            24       L. Messi  Lionel Andrés Messi Cuccittini
# 4         165153            24     K. Benzema                   Karim Benzema
# ...          ...           ...            ...                             ...
# 18345     273759            24       S. Telem             Saphaba Singh Telem
# 18346     269013            24  Jin Liangkuan                             金良宽
# 18347     272748            24      M. Mewlan                         买乌郎·米吉提
# 18348     269534            24        Yin Jie                              尹杰
# 18349     269541            24      Wu Yuhang                             吴宇航
#
# ...

# %%
fc_24['short_name'] = fc_24['short_name'].str.lower()
fc_24
# Out:
# C:\Users\jamor\AppData\Local\Temp/ipykernel_21508/1107108470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fc_24['short_name'] = fc_24['short_name'].str.lower()
#        player_id  fifa_version     short_name                       long_name  \
# 0         231747            24      k. mbappé            Kylian Mbappé Lottin
# 1         239085            24     e. haaland            Erling Braut Haaland
# 2         192985            24   k. de bruyne                 Kevin De Bruyne
# 3         158023            24       l. messi  Lionel Andrés Messi Cuccittini
# 4         165153            24     k. benzema                   Karim Benzema
# ...          ...           ...            ...                             ...
# ...

# %%
fc_24['short_name'] = fc_24['short_name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
fc_24
# Out:
# C:\Users\jamor\AppData\Local\Temp/ipykernel_21508/3190552845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fc_24['short_name'] = fc_24['short_name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
#        player_id  fifa_version     short_name                       long_name  \
# 0         231747            24      k. mbappe            Kylian Mbappé Lottin
# 1         239085            24     e. haaland            Erling Braut Haaland
# 2         192985            24   k. de bruyne                 Kevin De Bruyne
# 3         158023            24       l. messi  Lionel Andrés Messi Cuccittini
# 4         165153            24     k. benzema                   Karim Benzema
# ...

# %%
fc_24.to_csv('..\ChatGPT\gpt_food.csv')

# %%
current_squad = pd.read_csv('..\data\current_squad.csv')
current_squad
# Out:
#       short_name
# 0     a. kandlec
# 1     j. roberts
# 2    b. lefebvre
# 3        d. lang
# 4      p. cooper
# 5      c. santos
# 6     v. jonsson
# 7   s. contreras
# 8      v. santos
# 9     l. nygaard
# 10      d. leroy
# 11     g. santos
# 12      r. owusu
# 13      m. smith
# 14    m. coleman
# 15      g. busch
# 16      b. costa
# 17      j. jones
# 18    a. ibrahim
# 19      m. jones
# 20  s. demetriou
# 21      d. thiam
# 22    s. cameron

# %%
current_squad_stats = current_squad.merge(fc_24, on = 'short_name', how = 'left')

# %%
current_squad_stats
# Out:
#       short_name  player_id  fifa_version                           long_name  \
# 0     a. kandlec        NaN           NaN                                 NaN
# 1     j. roberts   206558.0          24.0              Jordan Stephen Roberts
# 2    b. lefebvre        NaN           NaN                                 NaN
# 3        d. lang        NaN           NaN                                 NaN
# 4      p. cooper        NaN           NaN                                 NaN
# 5      c. santos        NaN           NaN                                 NaN
# 6     v. jonsson   238195.0          24.0                   Viðar Ari Jónsson
# 7   s. contreras   256430.0          24.0  Simón Alberto Contreras Valenzuela
# 8      v. santos        NaN           NaN                                 NaN
# 9     l. nygaard        NaN           NaN                                 NaN
# 10      d. leroy        NaN           NaN                                 NaN
# ...

# %%
test = fc_24[fc_24['short_name'] == 's. contreras']
test
# Out:
# Empty DataFrame
# ...

# %%
fc_24['short_name'] = fc_24['short_name'].str.lower()
# Out:
# C:\Users\jamor\AppData\Local\Temp/ipykernel_21508/1206710272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fc_24['short_name'] = fc_24['short_name'].str.lower()

# %%
test = fc_24[fc_24['short_name'] == 's. contreras']
test
# Out:
#        player_id  fifa_version    short_name  \
# 11919     256430            24  s. contreras
#
#                                 long_name player_positions  overall  \
# 11919  Simón Alberto Contreras Valenzuela           ST, RW       63
#
#        potential  value_eur  wage_eur  age  ...   ldm   cdm   rdm   rwb    lb  \
# 11919         75  1200000.0     750.0   21  ...  40+2  40+2  40+2  43+2  40+2
#
#         lcb    cb   rcb    rb    gk
# 11919  36+2  36+2  36+2  40+2  16+2
#
# [1 rows x 99 columns]
